# %%
import dask.dataframe as dd
from dask.distributed import Client
import s3fs

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:34189' processes=8 threads=32, memory=62.43 GiB>

# %%
ddf = dd.read_parquet(
    "s3://coiled-data/uber/",
    columns=["tips"],
    storage_options={"anon": True},
)
